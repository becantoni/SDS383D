# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#%% get data
df=pd.read_csv('utilities.csv')
df = df.sort_values(by=['temp'])
y = df['gasbill'].to_numpy() / df['billingdays'].to_numpy()
X = (df['temp']).to_numpy()

# %%
from local_polynomial_regression import local_Linear

# %%
#create the object
lin = local_Linear(X, y)

# %%
#get h using LOOCV criterion
lin.LOOCV()
# Out:
# better chose h= 6.888888888888889

# %%
#E) plot fit 
lin.plot(h=6.9)

# %%
#F) 
plt.scatter(X, (lin.f-y), s=10, color='red')
plt.title('residuals scatterplot')
#make h specific to the area?
# Out:
# Text(0.5, 1.0, 'residuals scatterplot')

# %%
#G)
lin.plot_intervals(h=6.9)
# Out:
# 0.5682201053875973
# 0.27834791123357017
